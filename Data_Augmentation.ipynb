# %% [markdown]
# <a href="https://colab.research.google.com/github/luccidx/Data_Augmentation-to-genertate-N-Images-Data-for-creating-dataset/blob/main/Data_Augmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://drwyjmricaxm7.cloudfront.net/repository/Giant-Panda-sitting-on-forest-ground--China-Tours--On-The-Go-Tours-279771450457645_crop_800_600.jpg
# Out:
# --2020-10-06 04:48:04--  https://drwyjmricaxm7.cloudfront.net/repository/Giant-Panda-sitting-on-forest-ground--China-Tours--On-The-Go-Tours-279771450457645_crop_800_600.jpg
# Resolving drwyjmricaxm7.cloudfront.net (drwyjmricaxm7.cloudfront.net)... 13.33.201.219, 13.33.201.115, 13.33.201.81, ...
# Connecting to drwyjmricaxm7.cloudfront.net (drwyjmricaxm7.cloudfront.net)|13.33.201.219|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 75408 (74K) [image/jpeg]
# Saving to: ‘Giant-Panda-sitting-on-forest-ground--China-Tours--On-The-Go-Tours-279771450457645_crop_800_600.jpg’
#
# Giant-Panda-sitting 100%[===================>]  73.64K   150KB/s    in 0.5s
#
# 2020-10-06 04:48:06 (150 KB/s) - ‘Giant-Panda-sitting-on-forest-ground--China-Tours--On-The-Go-Tours-279771450457645_crop_800_600.jpg’ saved [75408/75408]

# %%
from PIL import Image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
import numpy as np

# %%
Image.open("Giant-Panda-sitting-on-forest-ground--China-Tours--On-The-Go-Tours-279771450457645_crop_800_600.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x600 at 0x7F591E7F4400>

# %%
! mkdir Images

# %%
print("Loading Image...")
image = load_img("Giant-Panda-sitting-on-forest-ground--China-Tours--On-The-Go-Tours-279771450457645_crop_800_600.jpg")
image = img_to_array(image)
image = np.expand_dims(image, axis=0)
# Out:
# Loading Image...

# %%
aug = ImageDataGenerator(rotation_range = 30, width_shift_range = 0.1 , height_shift_range=0.1,
                         zoom_range=0.2, horizontal_flip=True, fill_mode="nearest")

# %%
print("Generating images...")
imageGen = aug.flow(image, save_to_dir="./Images/", save_prefix="pandas", save_format=".jpg") 
n = 0
for image in imageGen:
  n = n+1
  if n==10:
    break
# Out:
# Generating images...
